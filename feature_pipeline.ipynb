# %%
def validate_feature(name, description, priority):

    errors = []

    if not name:
        errors.append("Feature name is required")

    if len(description) < 20:
        errors.append("Description must be at least 20 characters")

    if priority not in ["High", "Medium", "Low"]:
        errors.append("Invalid priority")

    if errors:
        return {"status": "Invalid", "errors": errors}

    return {"status": "Valid"}


feature_name = input("Enter Feature Name: ")
description = input("Enter Description: ")
priority = input("Enter Priority (High/Medium/Low): ")

result = validate_feature(
    feature_name,
    description,
    priority
)

print(result)
# Out:
# Enter Feature Name: Login System
# Enter Description: User can login using email and password
# Enter Priority (High/Medium/Low): High
# {'status': 'Valid'}
